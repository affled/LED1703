# %% [markdown]
# <a href="https://colab.research.google.com/github/affled/LED1703/blob/main/request2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/dar1.xlsx', header = 1).drop(columns=['Unnamed: 0', 'Unnamed: 13', 'Unnamed: 15'])
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   В/П  № рейса Код АП        Маршрут     Борт    Время рейса план  \
# 0   В  DP  204    VKO        ВНУКОВО  RA73232 2024-12-31 19:30:00
# 1   В  FZ  992    DXB          ДУБАЙ    A6FMJ 2025-01-01 00:25:00
# 2   В  2S  204    AYT        АНТАЛЬЯ    TCGRA 2025-01-01 01:30:00
# 3   П  JU  124    BEG        БЕЛГРАД    YUAPN 2025-01-01 04:05:00
# 4   В  SU  734    SSH  ШАРМ-ЭЛЬ-ШЕЙХ    73785 2025-01-01 04:00:00
#
#       Actual data time         ONB and OFB Компоновка  Вместимость  ...  Кл.1  \
# 0  2025-01-01 00:01:00 2024-12-31 23:53:00       Y189        189.0  ...   0.0
# 1  2025-01-01 01:03:00 2025-01-01 00:50:00        174        166.0  ...   0.0
# 2  2025-01-01 02:05:00 2025-01-01 01:46:00       Y345        312.0  ...   0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   В/П                   11269 non-null  object
#  1   № рейса               11269 non-null  object
#  2   Код АП                11268 non-null  object
#  3   Маршрут               11242 non-null  object
#  4   Борт                  11268 non-null  object
#  5   Время рейса план      11268 non-null  datetime64[ns]
#  6   Actual data time      11269 non-null  object
#  7   ONB and OFB           11268 non-null  datetime64[ns]
#  8   Компоновка            11252 non-null  object
#  9   Вместимость           11268 non-null  float64
#  10  Обслужено пассажиров  11267 non-null  float64
#  11  Взр                   11269 non-null  float64
#  12  Дети                  11269 non-null  float64
#  13  До 2-лет              11269 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# В/П                      2
# № рейса                  2
# Код АП                   3
# Маршрут                 29
# Борт                     3
# Время рейса план         3
# Actual data time         2
# ONB and OFB              3
# Компоновка              19
# Вместимость              3
# Обслужено пассажиров     4
# Взр                      2
# Дети                     2
# До 2-лет                 2
# Кл.1                     2
# Кл.2                     2
# Кл.3                     2
# МВМ, тонн                2
# Тип ВС                   3
# АВК                      3
# Направление              3
# Катег                    3
# Baggage Weight          28
# Spot Number              3
# dtype: int64

# %%
df.select_dtypes(include=['object']).describe()
# Out:
#           В/П  № рейса Код АП      Маршрут     Борт     Actual data time  \
# count   11269    11269  11268        11242    11268                11269
# unique      3      821    102          101      628                10765
# top         В  DP  572    SVO  ШЕРЕМЕТЬЕВО  RA73651  2025-01-18 22:57:00
# freq     5642       32   1703         1703      165                    3
#
#        Компоновка Тип ВС Направление  Катег Spot Number
# count       11252  11268       11268  11268       11268
# unique        200     30           2      4         106
# top        C12Y75    SU9    Domestic      J        106A
# freq         2360   3378        9370   9667         553

# %%
df.select_dtypes(include=['float64']).describe()
# Out:
#         Вместимость  Обслужено пассажиров           Взр          Дети  \
# count  11268.000000          1.126700e+04  1.126900e+04  11269.000000
# mean     147.469027          2.539123e+02  2.398177e+02     13.873281
# std       56.719575          1.347482e+04  1.272796e+04    736.331751
# min       19.000000          0.000000e+00  0.000000e+00      0.000000
# 25%       93.000000          8.400000e+01  8.000000e+01      2.000000
# 50%      148.000000          1.230000e+02  1.170000e+02      5.000000
# 75%      189.000000          1.710000e+02  1.610000e+02      9.000000
# max      457.000000          1.430415e+06  1.351253e+06  78169.000000
#
#            До 2-лет          Кл.1          Кл.2          Кл.3      МВМ, тонн  \
# count  11269.000000  11269.000000  11269.000000  1.126900e+04   11269.000000
# mean       1.851273      0.023250      6.928920  2.440838e+02     142.676610
# std       98.262639      1.258056    367.770554  1.295440e+04    7572.382994
# ...

# %%
group = df[['Код АП']].value_counts(normalize=True)*100
round(group.head(10),1)
# Out:
# Код АП
# SVO       15.1
# VKO        9.3
# KGD        5.9
# AER        3.9
# KZN        3.2
# MMK        2.9
# SVX        2.8
# ARH        2.8
# KUF        2.4
# UFA        2.2
# Name: proportion, dtype: float64

# %%
domestic_flights = df[df['Направление'] == 'Domestic']
group = df[['Код АП']].value_counts(normalize=True)*100
round(group.head(10),1)
# Out:
# Код АП
# SVO       15.1
# VKO        9.3
# KGD        5.9
# AER        3.9
# KZN        3.2
# MMK        2.9
# SVX        2.8
# ARH        2.8
# KUF        2.4
# UFA        2.2
# Name: proportion, dtype: float64

# %%
domestic_flights = df[df['Направление'] == 'Domestic']
international_flights = df[df['Направление'] == 'International']
group_1 = domestic_flights[['Код АП']].value_counts()
roup_2 = international_flights[['Код АП']].value_counts()

group_1.head(1)
# Out:
# Код АП
# SVO       1703
# Name: count, dtype: int64

# %%
df[((df['Катег'] == 'C') & (df['Маршрут'] == 'САЛЕХАРД'))]
# Out:
#      В/П  № рейса Код АП   Маршрут     Борт    Время рейса план  \
# 8941   П  YC 9715    SLY  САЛЕХАРД    67219 2025-01-24 19:00:00
# 9511   В  YC 9716    SLY  САЛЕХАРД  RA67219 2025-01-26 14:00:00
#
#          Actual data time         ONB and OFB Компоновка  Вместимость  ...  \
# 8941  2025-01-24 19:30:00 2025-01-24 19:34:00         14         19.0  ...
# 9511  2025-01-26 14:04:00 2025-01-26 14:02:00        C14         19.0  ...
#
#       Кл.1  Кл.2  Кл.3  МВМ, тонн  Тип ВС  АВК   Направление  Катег  \
# 8941   0.0   6.0   0.0      24.04     CR2   1.0     Domestic      C
# 9511   0.0   0.0   5.0      24.04     CR2   1.0     Domestic      C
#
#      Baggage Weight  Spot Number
# 8941           40.0          262
# 9511          180.0          262
#
# [2 rows x 24 columns]

# %%
group = df[((df['Катег'] == 'C') & (df['Маршрут'] == 'САЛЕХАРД'))]
group.sort_values(by="Baggage Weight", ascending=True)
# Out:
#      В/П  № рейса Код АП   Маршрут     Борт    Время рейса план  \
# 8941   П  YC 9715    SLY  САЛЕХАРД    67219 2025-01-24 19:00:00
# 9511   В  YC 9716    SLY  САЛЕХАРД  RA67219 2025-01-26 14:00:00
#
#          Actual data time         ONB and OFB Компоновка  Вместимость  ...  \
# 8941  2025-01-24 19:30:00 2025-01-24 19:34:00         14         19.0  ...
# 9511  2025-01-26 14:04:00 2025-01-26 14:02:00        C14         19.0  ...
#
#       Кл.1  Кл.2  Кл.3  МВМ, тонн  Тип ВС  АВК   Направление  Катег  \
# 8941   0.0   6.0   0.0      24.04     CR2   1.0     Domestic      C
# 9511   0.0   0.0   5.0      24.04     CR2   1.0     Domestic      C
#
#      Baggage Weight  Spot Number
# 8941           40.0          262
# 9511          180.0          262
#
# [2 rows x 24 columns]

# %%
# хотел сократить числа до 1 знака после запятой, но не вышло grouped_vm_vp["МВМ, тонн"] = grouped_vm_vp["МВМ, тонн"].round(0) и по вместимости аналогично, что пошло не так? пробовал в числа преоброзовать, тоже не пошло

df.groupby(['Направление', 'Тип ВС'])[["МВМ, тонн", "Вместимость"]].mean()
# Out:
#                        МВМ, тонн  Вместимость
# Направление   Тип ВС
# Domestic      319      70.077146   128.208817
#               320      76.406040   158.302013
#               321      89.170213   215.638298
#               32A      75.500000   151.274538
#               32B      91.113636   189.848485
#               32N      75.213415   176.170732
#               32Q      93.520468   237.549708
#               332     233.000000   361.476190
#               333     233.365385   298.692308
#               735      56.850000   126.000000
#               73G      70.080000   140.000000
#               73H      76.871667   188.229361
#               73W      67.269776   148.000000
#               77W     325.074000   420.333333
#               789     250.836000   290.000000
#               A26      24.000000    40.000000
#               CR1      24.040000    50.000000
#               CR2      24.034194    49.500000
#               E90      50.300000   110.000000
# ...
